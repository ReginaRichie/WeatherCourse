# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)

# %%
import requests

# %% [markdown]
# Получим в риалтайме данные по погоде

# %%
url = "https://weatherapi-com.p.rapidapi.com/current.json"

querystring = {"q": "53.1,-0.13"}

headers = {
    "X-RapidAPI-Key": "411d077234mshb947d578b6c66c3p12e921jsn3109f11069d4",
    "X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'location': {'name': 'Boston', 'region': 'Lincolnshire', 'country': 'United Kingdom', 'lat': 53.1, 'lon': -0.13, 'tz_id': 'Europe/London', 'localtime_epoch': 1683188049, 'localtime': '2023-05-04 9:14'}, 'current': {'last_updated_epoch': 1683187200, 'last_updated': '2023-05-04 09:00', 'temp_c': 10.0, 'temp_f': 50.0, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 15.0, 'wind_kph': 24.1, 'wind_degree': 90, 'wind_dir': 'E', 'pressure_mb': 1020.0, 'pressure_in': 30.12, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 87, 'cloud': 75, 'feelslike_c': 6.6, 'feelslike_f': 43.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 3.0, 'gust_mph': 23.9, 'gust_kph': 38.5}}

# %% [markdown]
# Получим погоду на 14 дней вперед

# %%
url = "https://weatherapi-com.p.rapidapi.com/forecast.json"

querystring = {"q":"Moscow ","days":"3"}

headers = {
	"X-RapidAPI-Key": "411d077234mshb947d578b6c66c3p12e921jsn3109f11069d4",
	"X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'location': {'name': 'Moscow', 'region': 'Moscow City', 'country': 'Russia', 'lat': 55.75, 'lon': 37.62, 'tz_id': 'Europe/Moscow', 'localtime_epoch': 1683188049, 'localtime': '2023-05-04 11:14'}, 'current': {'last_updated_epoch': 1683187200, 'last_updated': '2023-05-04 11:00', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 280, 'wind_dir': 'W', 'pressure_mb': 1024.0, 'pressure_in': 30.24, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 43, 'cloud': 0, 'feelslike_c': 10.9, 'feelslike_f': 51.6, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 4.0, 'gust_mph': 3.6, 'gust_kph': 5.8}, 'forecast': {'forecastday': [{'date': '2023-05-04', 'date_epoch': 1683158400, 'day': {'maxtemp_c': 15.9, 'maxtemp_f': 60.6, 'mintemp_c': 5.2, 'mintemp_f': 41.4, 'avgtemp_c': 10.5, 'avgtemp_f': 50.9, 'maxwind_mph': 8.5, 'maxwind_kph': 13.7, 'totalprecip_mm': 0.0, 'totalprecip_in': 0.0, 'totalsnow_cm': 0.0, 'avgvis_km': 10.0, 'avgvis_miles': 6.0, 'avghumidity': 42.0, 'daily_will_it_rain': 0, 'daily_chance_of_rain': 0, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'uv': 4.0}, 'astro': {'sunrise': '04:41 AM', 'sunset': '08:13 PM', 'moonrise': '06:45 PM', 'moonset': '04:20 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': '97', 'is_moon_up': 1, 'is_sun_up': 0}, 'hour': [{'time_epoch': 1683147600, 'time': '2023-05-04 00:00', 'temp_c': 7.1, 'temp_f': 44.8, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 4.0, 'wind_kph': 6.5, 'wind_degree': 348, 'wind_dir': 'NNW', 'pressure_mb': 1023.0, 'pressure_in': 30.21, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 57, 'cloud': 12, 'feelslike_c': 6.0, 'feelslike_f': 42.8, 'windchill_c': 6.0, 'windchill_f': 42.8, 'heatindex_c': 7.1, 'heatindex_f': 44.8, 'dewpoint_c': -0.9, 'dewpoint_f': 30.4, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 6.3, 'gust_kph': 10.1, 'uv': 1.0}, {'time_epoch': 1683151200, 'time': '2023-05-04 01:00', 'temp_c': 6.6, 'temp_f': 43.9, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 4.0, 'wind_kph': 6.5, 'wind_degree': 320, 'wind_dir': 'NW', 'pressure_mb': 1023.0, 'pressure_in': 30.22, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 58, 'cloud': 16, 'feelslike_c': 5.4, 'feelslike_f': 41.7, 'windchill_c': 5.4, 'windchill_f': 41.7, 'heatindex_c': 6.6, 'heatindex_f': 43.9, 'dewpoint_c': -1.1, 'dewpoint_f': 30.0, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 6.3, 'gust_kph': 10.1, 'uv': 1.0}, {'time_epoch': 1683154800, 'time': '2023-05-04 02:00', 'temp_c': 6.1, 'temp_f': 43.0, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 320, 'wind_dir': 'NW', 'pressure_mb': 1024.0, 'pressure_in': 30.23, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 59, 'cloud': 15, 'feelslike_c': 4.6, 'feelslike_f': 40.3, 'windchill_c': 4.6, 'windchill_f': 40.3, 'heatindex_c': 6.1, 'heatindex_f': 43.0, 'dewpoint_c': -1.3, 'dewpoint_f': 29.7, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 6.9, 'gust_kph': 11.2, 'uv': 1.0}, {'time_epoch': 1683158400, 'time': '2023-05-04 03:00', 'temp_c': 5.6, 'temp_f': 42.1, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 317, 'wind_dir': 'NW', 'pressure_mb': 1024.0, 'pressure_in': 30.24, 'precip_mm': 0.0, 'pre ...
